# %% [markdown]
# Idea: we read the `weirdshit` via lldb and then reverse the encryption.
#
# ```c
#       if (fgets(buf: &buf, n: 0x60, fp: __TMC_END__) == 0)
#           result = 1
#           puts(str: "Access denied.")
#       else
#           uint64_t rax_13 = strcspn(&buf, "\n")
#           buf[rax_13] = 0
#
#           if (rax_13 == 43)
#               void charbuffer
#               int64_t i = __builtin_memcpy(dest: &charbuffer, src: &buf, count: count)
#               void* rsi = &charbuffer
#
#               do
#                   int64_t rdx_6 = i s/ 7
#                   int64_t i_1 = i
#                   i += 1
#                   *rsi ^= *(&key + i_1 - rdx_6 * 7)
#                   rsi += 1
#               while (i != 0x2b)
#
#               int32_t result_1 = memcmp(&charbuffer, &weirdshit, 0x2b)
#               result = result_1
#
#               if (result_1 != 0)
#                   result = 1
#                   puts(str: "Access denied.")
#               else
#                   puts(str: "Access granted.")
#           else
#               result = 1
#               puts(str: "Access denied.")
# ```

# %% [markdown]
# Process 8739 launched: '/home/kali/Developer/mvmory/mvmory' (x86_64)
# asdasdasddasadsadsadadsadsadsadsdsadsasdasd
# Process 8739 stopped
# * thread #1, name = 'mvmory', stop reason = breakpoint 1.1
#     frame #0: 0x00007ffff7e25c60 libc.so.6`___lldb_unnamed_symbol4576
# libc.so.6`___lldb_unnamed_symbol4576:
# ->  0x7ffff7e25c60 <+0>:  cmpq   $0x20, %rdx
#     0x7ffff7e25c64 <+4>:  jb     0x7ffff7e25f40 ; <+736>
#     0x7ffff7e25c6a <+10>: vmovdqu (%rsi), %ymm1
#     0x7ffff7e25c6e <+14>: vpcmpeqb (%rdi), %ymm1, %ymm1
# (lldb) disassemble --pc --count 10
# libc.so.6`___lldb_unnamed_symbol4576:
# ->  0x7ffff7e25c60 <+0>:  cmpq   $0x20, %rdx
#     0x7ffff7e25c64 <+4>:  jb     0x7ffff7e25f40 ; <+736>
#     0x7ffff7e25c6a <+10>: vmovdqu (%rsi), %ymm1
#     0x7ffff7e25c6e <+14>: vpcmpeqb (%rdi), %ymm1, %ymm1
#     0x7ffff7e25c72 <+18>: vpmovmskb %ymm1, %eax
#     0x7ffff7e25c76 <+22>: incl   %eax
#     0x7ffff7e25c78 <+24>: jne    0x7ffff7e25d30 ; <+208>
#     0x7ffff7e25c7e <+30>: cmpq   $0x40, %rdx
#     0x7ffff7e25c82 <+34>: jbe    0x7ffff7e25ec4 ; <+612>
#     0x7ffff7e25c88 <+40>: vmovdqu 0x20(%rsi), %ymm2
# (lldb) finish
# Process 8739 stopped
# * thread #1, name = 'mvmory', stop reason = step out
#     frame #0: 0x00005555555552cb mvmory`main + 523
# mvmory`main:
# ->  0x5555555552cb <+523>: movl   %eax, %ebx
#     0x5555555552cd <+525>: testl  %eax, %eax
#     0x5555555552cf <+527>: jne    0x555555555200 ; <+320>
#     0x5555555552d5 <+533>: leaq   0xd39(%rip), %rdi
# (lldb) disassemble --pc --count 10
#
# (lldb) disassemble -s $pc-20 -c 40
# mvmory`main:
#     0x5555555552b7 <+503>: jne    0x555555555280 ; <+448>
#     0x5555555552b9 <+505>: movl   $0x2b, %edx
#     0x5555555552be <+510>: movq   %rbp, %rsi
#     0x5555555552c1 <+513>: leaq   0x40(%rsp), %rdi
#     0x5555555552c6 <+518>: callq  0x555555555060 ; symbol stub for: memcmp
# ->  0x5555555552cb <+523>: movl   %eax, %ebx
#     0x5555555552cd <+525>: testl  %eax, %eax
#     0x5555555552cf <+527>: jne    0x555555555200 ; <+320>
#     0x5555555552d5 <+533>: leaq   0xd39(%rip), %rdi
#     0x5555555552dc <+540>: callq  0x555555555030 ; symbol stub for: puts
#     0x5555555552e1 <+545>: jmp    0x555555555211 ; <+337>
#     0x5555555552e6 <+550>: movsd  %xmm1, (%rsp)
#     0x5555555552eb <+555>: movsd  %xmm5, 0x8(%rsp)
#     0x5555555552f1 <+561>: callq  0x555555555080 ; symbol stub for: sqrt
#     0x5555555552f6 <+566>: movsd  (%rsp), %xmm1
#     0x5555555552fb <+571>: subsd  0x8(%rsp), %xmm0
#     0x555555555301 <+577>: leaq   0xd58(%rip), %rsi ; ledger
#     0x555555555308 <+584>: movsd  0xea8(%rip), %xmm4
#     0x555555555310 <+592>: movsd  0xea8(%rip), %xmm3
#     0x555555555318 <+600>: pxor   %xmm2, %xmm2
#     0x55555555531c <+604>: addsd  %xmm1, %xmm1
#     0x555555555320 <+608>: divsd  %xmm1, %xmm0
#     0x555555555324 <+612>: jmp    0x5555555551af ; <+239>
#     0x555555555329 <+617>: callq  0x555555555040 ; symbol stub for: __stack_chk_fail
#     0x55555555532e:        nop
#
#
# (lldb) memory read --size 1 --count 45 --format x $rsi
# 0x7fffffffdb30: 0x3d 0x7f 0x56 0x66 0x5c 0x64 0x17 0x11
# 0x7fffffffdb38: 0x74 0x4a 0x7b 0x72 0x78 0x2c 0x62 0x78
# 0x7fffffffdb40: 0x6c 0x7c 0x29 0x78 0x37 0x62 0x63 0x45
# 0x7fffffffdb48: 0x3b 0x46 0x53 0x2c 0x63 0x3a 0x6c 0x7f
# 0x7fffffffdb50: 0x29 0x4c 0x77 0x3c 0x50 0x52 0x7c 0x46
# 0x7fffffffdb58: 0x17 0x74 0x2f 0x00 0x00
# (lldb) memory read --size 1 --count 45 --format x $rsi
# 0x7fffffffdb30: 0x3d 0x7f 0x56 0x66 0x5c 0x64 0x17 0x11
# 0x7fffffffdb38: 0x74 0x4a 0x7b 0x72 0x78 0x2c 0x62 0x78
# 0x7fffffffdb40: 0x6c 0x7c 0x29 0x78 0x37 0x62 0x63 0x45
# 0x7fffffffdb48: 0x3b 0x46 0x53 0x2c 0x63 0x3a 0x6c 0x7f
# 0x7fffffffdb50: 0x29 0x4c 0x77 0x3c 0x50 0x52 0x7c 0x46
# 0x7fffffffdb58: 0x17 0x74 0x2f 0x00 0x00
#
# (lldb) memory read --size 1 --count 43 --format c $rdi
# 0x7fffffffdb60: 3|WijC%!kWijF !nW{xC%6|RljF !nW{
# 0x7fffffffdb80: }T%6|R{}F76
# (lldb) memory read --size 1 --count 43 --format c $rsi
# 0x7fffffffdb30: =\x7fVf\d\x17\x11tJ{rx,bxl|)x7bcE;FS,c:l\x7f)Lw<PR|F\x17t/
# 0x7fffffffdb50: )Lw<PR|F\x17t/
#
#
# echo -e "=\x7fVf\d\x17\x11tJ{rx,bxl|)x7bcE;FS,c:l\x7f" | ./mvmory
#
# (lldb) process launch --stdin input.bin
# Process 3280 launched: '/home/kali/Developer/mvmory/mvmory' (x86_64)
# Process 3280 stopped
# * thread #1, name = 'mvmory', stop reason = breakpoint 1.1
#     frame #0: 0x00007ffff7e25c60 libc.so.6`___lldb_unnamed_symbol4576
# libc.so.6`___lldb_unnamed_symbol4576:
# ->  0x7ffff7e25c60 <+0>:  cmpq   $0x20, %rdx
#     0x7ffff7e25c64 <+4>:  jb     0x7ffff7e25f40 ; <+736>
#     0x7ffff7e25c6a <+10>: vmovdqu (%rsi), %ymm1
#     0x7ffff7e25c6e <+14>: vpcmpeqb (%rdi), %ymm1, %ymm1
# (lldb) f
# frame #0: 0x00007ffff7e25c60 libc.so.6`___lldb_unnamed_symbol4576
# libc.so.6`___lldb_unnamed_symbol4576:
# ->  0x7ffff7e25c60 <+0>:  cmpq   $0x20, %rdx
#     0x7ffff7e25c64 <+4>:  jb     0x7ffff7e25f40 ; <+736>
#     0x7ffff7e25c6a <+10>: vmovdqu (%rsi), %ymm1
#     0x7ffff7e25c6e <+14>: vpcmpeqb (%rdi), %ymm1, %ymm1
# (lldb) f
# frame #0: 0x00007ffff7e25c60 libc.so.6`___lldb_unnamed_symbol4576
# libc.so.6`___lldb_unnamed_symbol4576:
# ->  0x7ffff7e25c60 <+0>:  cmpq   $0x20, %rdx
#     0x7ffff7e25c64 <+4>:  jb     0x7ffff7e25f40 ; <+736>
#     0x7ffff7e25c6a <+10>: vmovdqu (%rsi), %ymm1
#     0x7ffff7e25c6e <+14>: vpcmpeqb (%rdi), %ymm1, %ymm1
# (lldb) finish
# Process 3280 stopped
# * thread #1, name = 'mvmory', stop reason = step out
#     frame #0: 0x00005555555552cb mvmory`main + 523
# mvmory`main:
# ->  0x5555555552cb <+523>: movl   %eax, %ebx
#     0x5555555552cd <+525>: testl  %eax, %eax
#     0x5555555552cf <+527>: jne    0x555555555200 ; <+320>
#     0x5555555552d5 <+533>: leaq   0xd39(%rip), %rdi
# (lldb) d
# Ambiguous command 'd'. Possible matches:
#         diagnostics
#         disassemble
#         dwim-print
#         detach
#         di
#         dis
#         display
#         down
# (lldb) dis
# mvmory`main:
#     0x5555555550c0 <+0>:   pushq  %r12
#     0x5555555550c2 <+2>:   leaq   0xf97(%rip), %rsi ; ledger
#     0x5555555550c9 <+9>:   pxor   %xmm2, %xmm2
#     0x5555555550cd <+13>:  movabsq $-0x3333333333333333, %r12 ; imm = 0xCCCCCCCCCCCCCCCD
#     0x5555555550d7 <+23>:  pushq  %rbp
#     0x5555555550d8 <+24>:  pushq  %rbx
#     0x5555555550d9 <+25>:  subq   $0xe0, %rsp
#     0x5555555550e0 <+32>:  movsd  0x10d0(%rip), %xmm4
#     0x5555555550e8 <+40>:  movsd  0x10d0(%rip), %xmm3
#     0x5555555550f0 <+48>:  movq   %fs:0x28, %rbx
#     0x5555555550f9 <+57>:  movq   %rbx, 0xd8(%rsp)
#     0x555555555101 <+65>:  xorl   %ebx, %ebx
#     0x555555555103 <+67>:  leaq   0x10(%rsp), %rbp
#     0x555555555108 <+72>:  nopl   (%rax,%rax)
#     0x555555555110 <+80>:  pxor   %xmm1, %xmm1
#     0x555555555114 <+84>:  pxor   %xmm5, %xmm5
#     0x555555555118 <+88>:  pxor   %xmm7, %xmm7
#     0x55555555511c <+92>:  movq   %rbx, %rax
#     0x55555555511f <+95>:  movabsq $0x4d8f3a51e29b907c, %rdi ; imm = 0x4D8F3A51E29B907C
#     0x555555555129 <+105>: mulq   %r12
#     0x55555555512c <+108>: xorq   (%rsi,%rbx,8), %rdi
#     0x555555555130 <+112>: cvtsi2sd %edi, %xmm7
#     0x555555555134 <+116>: movq   %rdx, %rax
#     0x555555555137 <+119>: andq   $-0x4, %rdx
#     0x55555555513b <+123>: shrq   $0x2, %rax
#     0x55555555513f <+127>: addq   %rax, %rdx
#     0x555555555142 <+130>: movq   %rbx, %rax
#     0x555555555145 <+133>: subq   %rdx, %rax
#     0x555555555148 <+136>: addl   $0x1, %eax
#     0x55555555514b <+139>: cvtsi2sd %eax, %xmm1
#     0x55555555514f <+143>: movapd %xmm1, %xmm6
#     0x555555555153 <+147>: movq   %rdi, %rax
#     0x555555555156 <+150>: mulsd  %xmm4, %xmm6
#     0x55555555515a <+154>: shrq   $0x20, %rax
#     0x55555555515e <+158>: negl   %eax
#     0x555555555160 <+160>: cvtsi2sd %eax, %xmm5
#     0x555555555164 <+164>: movapd %xmm5, %xmm0
#     0x555555555168 <+168>: mulsd  %xmm5, %xmm0
#     0x55555555516c <+172>: mulsd  %xmm7, %xmm6
#     0x555555555170 <+176>: subsd  %xmm6, %xmm0
#     0x555555555174 <+180>: ucomisd %xmm0, %xmm2
#     0x555555555178 <+184>: ja     0x5555555552e6 ; <+550>
#     0x55555555517e <+190>: sqrtsd %xmm0, %xmm0
#     0x555555555182 <+194>: addsd  %xmm1, %xmm1
#     0x555555555186 <+198>: subsd  %xmm5, %xmm0
#     0x55555555518a <+202>: divsd  %xmm1, %xmm0
#     0x55555555518e <+206>: movapd %xmm0, %xmm5
#     0x555555555192 <+210>: movapd %xmm0, %xmm1
#     0x555555555196 <+214>: xorpd  0x1032(%rip), %xmm1
#     0x55555555519e <+222>: cmpltsd %xmm2, %xmm0
#     0x5555555551a3 <+227>: andpd  %xmm0, %xmm1
#     0x5555555551a7 <+231>: andnpd %xmm5, %xmm0
#     0x5555555551ab <+235>: orpd   %xmm1, %xmm0
#     0x5555555551af <+239>: addsd  %xmm3, %xmm0
#     0x5555555551b3 <+243>: cvttsd2si %xmm0, %eax
#     0x5555555551b7 <+247>: movb   %al, (%rbp,%rbx)
#     0x5555555551bb <+251>: addq   $0x1, %rbx
#     0x5555555551bf <+255>: cmpq   $0x2b, %rbx
#     0x5555555551c3 <+259>: jne    0x555555555110 ; <+80>
#     0x5555555551c9 <+265>: movq   0x2e70(%rip), %rdx ; stdin@GLIBC_2.2.5
#     0x5555555551d0 <+272>: movl   $0x60, %esi
#     0x5555555551d5 <+277>: leaq   0x70(%rsp), %rdi
#     0x5555555551da <+282>: callq  0x555555555070 ; symbol stub for: fgets
#     0x5555555551df <+287>: testq  %rax, %rax
#     0x5555555551e2 <+290>: je     0x555555555200 ; <+320>
#     0x5555555551e4 <+292>: leaq   0xe28(%rip), %rsi
#     0x5555555551eb <+299>: leaq   0x70(%rsp), %rdi
#     0x5555555551f0 <+304>: callq  0x555555555050 ; symbol stub for: strcspn
#     0x5555555551f5 <+309>: movb   $0x0, 0x70(%rsp,%rax)
#     0x5555555551fa <+314>: cmpq   $0x2b, %rax
#     0x5555555551fe <+318>: je     0x555555555236 ; <+374>
#     0x555555555200 <+320>: leaq   0xdfd(%rip), %rdi
#     0x555555555207 <+327>: movl   $0x1, %ebx
#     0x55555555520c <+332>: callq  0x555555555030 ; symbol stub for: puts
#     0x555555555211 <+337>: movq   0xd8(%rsp), %rax
#     0x555555555219 <+345>: subq   %fs:0x28, %rax
#     0x555555555222 <+354>: jne    0x555555555329 ; <+617>
#     0x555555555228 <+360>: addq   $0xe0, %rsp
#     0x55555555522f <+367>: movl   %ebx, %eax
#     0x555555555231 <+369>: popq   %rbx
#     0x555555555232 <+370>: popq   %rbp
#     0x555555555233 <+371>: popq   %r12
#     0x555555555235 <+373>: retq
#     0x555555555236 <+374>: leaq   0x40(%rsp), %rdi
#     0x55555555523b <+379>: leaq   0x70(%rsp), %rsi
#     0x555555555240 <+384>: movq   %rbx, %rcx
#     0x555555555243 <+387>: rep    movsb (%rsi), %es:(%rdi)
#     0x555555555245 <+389>: leaq   0xdf4(%rip), %r9 ; key
#     0x55555555524c <+396>: leaq   0x40(%rsp), %rsi
#     0x555555555251 <+401>: movabsq $0x4924924924924925, %rdi ; imm = 0x4924924924924925
#     0x55555555525b <+411>: nopl   (%rax)
#     0x55555555525f <+415>: nopw   %cs:(%rax,%rax)
#     0x55555555526a <+426>: nopw   %cs:(%rax,%rax)
#     0x555555555275 <+437>: nopw   %cs:(%rax,%rax)
#     0x555555555280 <+448>: movq   %rcx, %rax
#     0x555555555283 <+451>: imulq  %rdi
#     0x555555555286 <+454>: movq   %rcx, %rax
#     0x555555555289 <+457>: sarq   $0x3f, %rax
#     0x55555555528d <+461>: sarq   %rdx
#     0x555555555290 <+464>: subq   %rax, %rdx
#     0x555555555293 <+467>: leaq   (,%rdx,8), %rax
#     0x55555555529b <+475>: subq   %rdx, %rax
#     0x55555555529e <+478>: movq   %rcx, %rdx
#     0x5555555552a1 <+481>: addq   $0x1, %rcx
#     0x5555555552a5 <+485>: subq   %rax, %rdx
#     0x5555555552a8 <+488>: movzbl (%r9,%rdx), %eax
#     0x5555555552ad <+493>: xorb   %al, (%rsi)
#     0x5555555552af <+495>: addq   $0x1, %rsi
#     0x5555555552b3 <+499>: cmpq   $0x2b, %rcx
#     0x5555555552b7 <+503>: jne    0x555555555280 ; <+448>
#     0x5555555552b9 <+505>: movl   $0x2b, %edx
#     0x5555555552be <+510>: movq   %rbp, %rsi
#     0x5555555552c1 <+513>: leaq   0x40(%rsp), %rdi
#     0x5555555552c6 <+518>: callq  0x555555555060 ; symbol stub for: memcmp
# ->  0x5555555552cb <+523>: movl   %eax, %ebx
#     0x5555555552cd <+525>: testl  %eax, %eax
#     0x5555555552cf <+527>: jne    0x555555555200 ; <+320>
#     0x5555555552d5 <+533>: leaq   0xd39(%rip), %rdi
#     0x5555555552dc <+540>: callq  0x555555555030 ; symbol stub for: puts
#     0x5555555552e1 <+545>: jmp    0x555555555211 ; <+337>
#     0x5555555552e6 <+550>: movsd  %xmm1, (%rsp)
#     0x5555555552eb <+555>: movsd  %xmm5, 0x8(%rsp)
#     0x5555555552f1 <+561>: callq  0x555555555080 ; symbol stub for: sqrt
#     0x5555555552f6 <+566>: movsd  (%rsp), %xmm1
#     0x5555555552fb <+571>: subsd  0x8(%rsp), %xmm0
#     0x555555555301 <+577>: leaq   0xd58(%rip), %rsi ; ledger
#     0x555555555308 <+584>: movsd  0xea8(%rip), %xmm4
#     0x555555555310 <+592>: movsd  0xea8(%rip), %xmm3
#     0x555555555318 <+600>: pxor   %xmm2, %xmm2
#     0x55555555531c <+604>: addsd  %xmm1, %xmm1
#     0x555555555320 <+608>: divsd  %xmm1, %xmm0
#     0x555555555324 <+612>: jmp    0x5555555551af ; <+239>
#     0x555555555329 <+617>: callq  0x555555555040 ; symbol stub for: __stack_chk_fail
# (lldb)
# mvmory`main:
#     0x5555555550c0 <+0>:   pushq  %r12
#     0x5555555550c2 <+2>:   leaq   0xf97(%rip), %rsi ; ledger
#     0x5555555550c9 <+9>:   pxor   %xmm2, %xmm2
#     0x5555555550cd <+13>:  movabsq $-0x3333333333333333, %r12 ; imm = 0xCCCCCCCCCCCCCCCD
#     0x5555555550d7 <+23>:  pushq  %rbp
#     0x5555555550d8 <+24>:  pushq  %rbx
#     0x5555555550d9 <+25>:  subq   $0xe0, %rsp
#     0x5555555550e0 <+32>:  movsd  0x10d0(%rip), %xmm4
#     0x5555555550e8 <+40>:  movsd  0x10d0(%rip), %xmm3
#     0x5555555550f0 <+48>:  movq   %fs:0x28, %rbx
#     0x5555555550f9 <+57>:  movq   %rbx, 0xd8(%rsp)
#     0x555555555101 <+65>:  xorl   %ebx, %ebx
#     0x555555555103 <+67>:  leaq   0x10(%rsp), %rbp
#     0x555555555108 <+72>:  nopl   (%rax,%rax)
#     0x555555555110 <+80>:  pxor   %xmm1, %xmm1
#     0x555555555114 <+84>:  pxor   %xmm5, %xmm5
#     0x555555555118 <+88>:  pxor   %xmm7, %xmm7
#     0x55555555511c <+92>:  movq   %rbx, %rax
#     0x55555555511f <+95>:  movabsq $0x4d8f3a51e29b907c, %rdi ; imm = 0x4D8F3A51E29B907C
#     0x555555555129 <+105>: mulq   %r12
#     0x55555555512c <+108>: xorq   (%rsi,%rbx,8), %rdi
#     0x555555555130 <+112>: cvtsi2sd %edi, %xmm7
#     0x555555555134 <+116>: movq   %rdx, %rax
#     0x555555555137 <+119>: andq   $-0x4, %rdx
#     0x55555555513b <+123>: shrq   $0x2, %rax
#     0x55555555513f <+127>: addq   %rax, %rdx
#     0x555555555142 <+130>: movq   %rbx, %rax
#     0x555555555145 <+133>: subq   %rdx, %rax
#     0x555555555148 <+136>: addl   $0x1, %eax
#     0x55555555514b <+139>: cvtsi2sd %eax, %xmm1
#     0x55555555514f <+143>: movapd %xmm1, %xmm6
#     0x555555555153 <+147>: movq   %rdi, %rax
#     0x555555555156 <+150>: mulsd  %xmm4, %xmm6
#     0x55555555515a <+154>: shrq   $0x20, %rax
#     0x55555555515e <+158>: negl   %eax
#     0x555555555160 <+160>: cvtsi2sd %eax, %xmm5
#     0x555555555164 <+164>: movapd %xmm5, %xmm0
#     0x555555555168 <+168>: mulsd  %xmm5, %xmm0
#     0x55555555516c <+172>: mulsd  %xmm7, %xmm6
#     0x555555555170 <+176>: subsd  %xmm6, %xmm0
#     0x555555555174 <+180>: ucomisd %xmm0, %xmm2
#     0x555555555178 <+184>: ja     0x5555555552e6 ; <+550>
#     0x55555555517e <+190>: sqrtsd %xmm0, %xmm0
#     0x555555555182 <+194>: addsd  %xmm1, %xmm1
#     0x555555555186 <+198>: subsd  %xmm5, %xmm0
#     0x55555555518a <+202>: divsd  %xmm1, %xmm0
#     0x55555555518e <+206>: movapd %xmm0, %xmm5
#     0x555555555192 <+210>: movapd %xmm0, %xmm1
#     0x555555555196 <+214>: xorpd  0x1032(%rip), %xmm1
#     0x55555555519e <+222>: cmpltsd %xmm2, %xmm0
#     0x5555555551a3 <+227>: andpd  %xmm0, %xmm1
#     0x5555555551a7 <+231>: andnpd %xmm5, %xmm0
#     0x5555555551ab <+235>: orpd   %xmm1, %xmm0
#     0x5555555551af <+239>: addsd  %xmm3, %xmm0
#     0x5555555551b3 <+243>: cvttsd2si %xmm0, %eax
#     0x5555555551b7 <+247>: movb   %al, (%rbp,%rbx)
#     0x5555555551bb <+251>: addq   $0x1, %rbx
#     0x5555555551bf <+255>: cmpq   $0x2b, %rbx
#     0x5555555551c3 <+259>: jne    0x555555555110 ; <+80>
#     0x5555555551c9 <+265>: movq   0x2e70(%rip), %rdx ; stdin@GLIBC_2.2.5
#     0x5555555551d0 <+272>: movl   $0x60, %esi
#     0x5555555551d5 <+277>: leaq   0x70(%rsp), %rdi
#     0x5555555551da <+282>: callq  0x555555555070 ; symbol stub for: fgets
#     0x5555555551df <+287>: testq  %rax, %rax
#     0x5555555551e2 <+290>: je     0x555555555200 ; <+320>
#     0x5555555551e4 <+292>: leaq   0xe28(%rip), %rsi
#     0x5555555551eb <+299>: leaq   0x70(%rsp), %rdi
#     0x5555555551f0 <+304>: callq  0x555555555050 ; symbol stub for: strcspn
#     0x5555555551f5 <+309>: movb   $0x0, 0x70(%rsp,%rax)
#     0x5555555551fa <+314>: cmpq   $0x2b, %rax
#     0x5555555551fe <+318>: je     0x555555555236 ; <+374>
#     0x555555555200 <+320>: leaq   0xdfd(%rip), %rdi
#     0x555555555207 <+327>: movl   $0x1, %ebx
#     0x55555555520c <+332>: callq  0x555555555030 ; symbol stub for: puts
#     0x555555555211 <+337>: movq   0xd8(%rsp), %rax
#     0x555555555219 <+345>: subq   %fs:0x28, %rax
#     0x555555555222 <+354>: jne    0x555555555329 ; <+617>
#     0x555555555228 <+360>: addq   $0xe0, %rsp
#     0x55555555522f <+367>: movl   %ebx, %eax
#     0x555555555231 <+369>: popq   %rbx
#     0x555555555232 <+370>: popq   %rbp
#     0x555555555233 <+371>: popq   %r12
#     0x555555555235 <+373>: retq
#     0x555555555236 <+374>: leaq   0x40(%rsp), %rdi
#     0x55555555523b <+379>: leaq   0x70(%rsp), %rsi
#     0x555555555240 <+384>: movq   %rbx, %rcx
#     0x555555555243 <+387>: rep    movsb (%rsi), %es:(%rdi)
#     0x555555555245 <+389>: leaq   0xdf4(%rip), %r9 ; key
#     0x55555555524c <+396>: leaq   0x40(%rsp), %rsi
#     0x555555555251 <+401>: movabsq $0x4924924924924925, %rdi ; imm = 0x4924924924924925
#     0x55555555525b <+411>: nopl   (%rax)
#     0x55555555525f <+415>: nopw   %cs:(%rax,%rax)
#     0x55555555526a <+426>: nopw   %cs:(%rax,%rax)
#     0x555555555275 <+437>: nopw   %cs:(%rax,%rax)
#     0x555555555280 <+448>: movq   %rcx, %rax
#     0x555555555283 <+451>: imulq  %rdi
#     0x555555555286 <+454>: movq   %rcx, %rax
#     0x555555555289 <+457>: sarq   $0x3f, %rax
#     0x55555555528d <+461>: sarq   %rdx
#     0x555555555290 <+464>: subq   %rax, %rdx
#     0x555555555293 <+467>: leaq   (,%rdx,8), %rax
#     0x55555555529b <+475>: subq   %rdx, %rax
#     0x55555555529e <+478>: movq   %rcx, %rdx
#     0x5555555552a1 <+481>: addq   $0x1, %rcx
#     0x5555555552a5 <+485>: subq   %rax, %rdx
#     0x5555555552a8 <+488>: movzbl (%r9,%rdx), %eax
#     0x5555555552ad <+493>: xorb   %al, (%rsi)
#     0x5555555552af <+495>: addq   $0x1, %rsi
#     0x5555555552b3 <+499>: cmpq   $0x2b, %rcx
#     0x5555555552b7 <+503>: jne    0x555555555280 ; <+448>
#     0x5555555552b9 <+505>: movl   $0x2b, %edx
#     0x5555555552be <+510>: movq   %rbp, %rsi
#     0x5555555552c1 <+513>: leaq   0x40(%rsp), %rdi
#     0x5555555552c6 <+518>: callq  0x555555555060 ; symbol stub for: memcmp
# ->  0x5555555552cb <+523>: movl   %eax, %ebx
#     0x5555555552cd <+525>: testl  %eax, %eax
#     0x5555555552cf <+527>: jne    0x555555555200 ; <+320>
#     0x5555555552d5 <+533>: leaq   0xd39(%rip), %rdi
#     0x5555555552dc <+540>: callq  0x555555555030 ; symbol stub for: puts
#     0x5555555552e1 <+545>: jmp    0x555555555211 ; <+337>
#     0x5555555552e6 <+550>: movsd  %xmm1, (%rsp)
#     0x5555555552eb <+555>: movsd  %xmm5, 0x8(%rsp)
#     0x5555555552f1 <+561>: callq  0x555555555080 ; symbol stub for: sqrt
#     0x5555555552f6 <+566>: movsd  (%rsp), %xmm1
#     0x5555555552fb <+571>: subsd  0x8(%rsp), %xmm0
#     0x555555555301 <+577>: leaq   0xd58(%rip), %rsi ; ledger
#     0x555555555308 <+584>: movsd  0xea8(%rip), %xmm4
#     0x555555555310 <+592>: movsd  0xea8(%rip), %xmm3
#     0x555555555318 <+600>: pxor   %xmm2, %xmm2
#     0x55555555531c <+604>: addsd  %xmm1, %xmm1
#     0x555555555320 <+608>: divsd  %xmm1, %xmm0
#     0x555555555324 <+612>: jmp    0x5555555551af ; <+239>
#     0x555555555329 <+617>: callq  0x555555555040 ; symbol stub for: __stack_chk_fail
# (lldb) m re
# Available completions:
#         read   -- Read from the memory of the current target process.
#         region -- Get information on the memory region containing an address in the current target process.
# (lldb) m re
# ambiguous command 'memory re'. Possible completions:
#         read
#         region
# (lldb) m read
# error: memory read takes a start address expression with an optional end address expression.
# warning: Expressions should be quoted if they contain spaces or other special characters.
# (lldb) m read --size 1 --count 45 --format c %rsi
# error: invalid start address expression.
# error: address expression "%rsi" evaluation failed
# (lldb) m read --size 1 --count 45 --format c $rsi
# 0x7fffffffdb80: =\x7fVf\d\x17\x11tJ{rx,bxl|)x7bcE;FS,c:l\x7f
# 0x7fffffffdba0: )Lw<PR|F\x17t/\0\0
# (lldb) m read --size 1 --count 45 --format c $rdi
# 0x7fffffffdbb0: openECSC{ysk_h0w_t0_s0lv3_th15_w
# 0x7fffffffdbd0: 0k3n_at_00}\0\0
# (lldb)

# %% [markdown]
# ```c
#   int32_t main(int32_t argc, char** argv, char** envp)
#
#       int64_t zmm2 = (zx.o(0)).q
#       double zmm4 = 4.0
#       int64_t zmm3 = 0x3fe0000000000000
#       void* fsbase
#       int64_t rbx = *(fsbase + 0x28)
#       char var_e8[0x30]
#       int64_t count
#
#       for (count = 0; count != 0x2b; count += 1)
#           uint64_t zmm1[0x2] = zx.o(0)
#           double zmm5[0x2] = zx.o(0)
#           int64_t rax_2
#           int64_t rdx
#           rdx:rax_2 = mulu.dp.q(count, -0x3333333333333333)
#           int64_t rdi = 0x4d8f3a51e29b907c ^ *(&ledger + (count << 3))
#           zmm1[0] = float.d(count.d - ((rdx.d & 0xfffffffc) + (count u/ 5).d) + 1)
#           uint64_t zmm6 = zmm1[0] f* zmm4
#           zmm5[0] = float.d(neg.d((rdi u>> 0x20).d))
#           zmm5[0] = zmm5[0] * zmm5[0]
#           zmm5[0] = zmm5[0] f- zmm6 f* float.d(rdi.d)
#           double zmm0[0x2]
#
#           if (zmm2 f> zmm5[0])
#               zmm0 = sqrt(x: zmm5[0])
#               zmm1 = zx.o(zmm1.q)
#               zmm0[0] = zmm0[0] f- zmm5.q
#               zmm4 = 4.0
#               zmm3 = 0x3fe0000000000000
#               zmm2 = (zx.o(0)).q
#               zmm1[0] = zmm1[0] f+ zmm1[0]
#               zmm0[0] = zmm0[0] f/ zmm1[0]
#           else
#               double temp0_1[0x2] = _mm_sqrt_sd(zmm5[0], zmm5[0])
#               zmm1[0] = zmm1[0] f+ zmm1[0]
#               temp0_1[0] = temp0_1[0] - zmm5[0]
#               temp0_1[0] = temp0_1[0] f/ zmm1[0]
#               uint64_t temp0_2[0x2] = __xorpd_xmmxuq_memxuq(temp0_1, data_4021d0)
#               double temp0_3[0x2] = _mm_cmpeq_sd(temp0_1[0], zmm2, 1)
#               uint64_t temp0_4[0x2] = _mm_and_pd(temp0_2, temp0_3)
#               zmm0 = _mm_or_pd(_mm_andnot_pd(temp0_3, temp0_1), temp0_4)
#
#           zmm0[0] = zmm0[0] f+ zmm3
#           var_e8[count] = (int.d(zmm0[0])).b
#
#       char buf[0x68]
#       int32_t result
#
#       if (fgets(buf: &buf, n: 0x60, fp: __TMC_END__) == 0)
#           result = 1
#           puts(str: "Access denied.")
#       else
#           uint64_t rax_13 = strcspn(&buf, "\n")
#           buf[rax_13] = 0
#
#           if (rax_13 == 0x2b)
#               void var_b8
#               int64_t i = __builtin_memcpy(dest: &var_b8, src: &buf, count: count)
#               void* rsi = &var_b8
#
#               do
#                   int64_t rdx_6 = i s/ 7
#                   int64_t i_1 = i
#                   i += 1
#                   *rsi ^= *(&key + i_1 - rdx_6 * 7)
#                   rsi += 1
#               while (i != 0x2b)
#
#               int32_t result_1 = memcmp(&var_b8, &var_e8, 43)
#               result = result_1
#
#               if (result_1 != 0)
#                   result = 1
#                   puts(str: "Access denied.")
#               else
#                   puts(str: "Access granted.")
#           else
#               result = 1
#               puts(str: "Access denied.")
#
#       *(fsbase + 0x28)
#
#       if (rbx == *(fsbase + 0x28))
#           return result
#
#       __stack_chk_fail()
#       noreturn
# ```
