# %%
"""
Our brand new baker, ElGamal, has whipped up the most wonderful cheesecake you could ever imagine. Seriously, it's so good it might encrypt your taste buds.

But... there's a problem. One mysterious ingredient is missing from the recipe!
Can you crack the code and figure out what ElGamal forgot to mix in?

The suspiciously scrambled recipe says this:
"""

p  = 14912432766367177751
g  = 2784687438861268863
h  = 8201777436716393968
c1 = 12279519522290406516
c2 = 10734305369677133991


"""
el gamal is:

Fp is a field where G is subgroup with prime order that divides p-1

c1,c2 = g^r, g^ar * m

apparently, h = g^a


"""


"""
The flag is the recovered plaintext, wrapped in brunner{}.
Example: If you found c4rr0t5, the flag should be submitted as brunner{c4rr0t5}.
"""
# Out:
# '\nThe flag is the recovered plaintext, wrapped in brunner{}.\nExample: If you found c4rr0t5, the flag should be submitted as brunner{c4rr0t5}.\n'

# %%
from sage.all import *
import math

# %%
prime_divisors(14912432766367177751)
# Out:
# [14912432766367177751]

# %%
Fp = GF(p)
g  = Fp(g)
h  = Fp(h)
c1 = Fp(c1)
c2 = Fp(c2)

# %%
assert p == g.order()

# %%
discrete_log_rho(
    h,g,g.order(),"*"
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 discrete_log_rho(
#       2     h,g,g.order(),"*"
#       3 )
#
# File ~/miniconda3/envs/sage/lib/python3.12/site-packages/sage/groups/generic.py:663, in discrete_log_rho(a, base, ord, operation, identity, inverse, op, hash_function)
#     660 for i in range(reset_bound):
#     661     # random walk, we need an efficient hash
#     662     s = hash_function(x) % partition_size
# --> 663     x, ax, bx = (mult(M[s], x), ax + m[s], bx + n[s])
#     664     if mut:
#     665         x.set_immutable()
#
# KeyboardInterrupt:
