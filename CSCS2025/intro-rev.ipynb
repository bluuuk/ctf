# %% [markdown]
# # Intro 1
#
# Use strings :)

# %% [markdown]
# # Intro 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ciphertext = b"\x02\xea\x02\xe8\xfc\xfd\xbd\xfd\xf2\xec\xe8\xfd\xfb\xea\xf7\xfc\xef\xb9\xfb\xf6\xea\xfd\xf2\xf8\xf7"
plaintext = bytes([(int(x)+0x77)%256 for x in ciphertext])
plaintext
# Out:
# b'yay_st4tic_transf0rmation'

# %%
# %%bash
# (sleep 1 && echo "yay_st4tic_transf0rmation") | ncat --ssl-verify dc60102840c42fab51e73598-1024-intro-rev-2.challenge.cscg.live 1337
# Out:
# Give me your password:
# Thats the right password!
# Flag: CSCG{y0u_just_r3versed_a_st4tic_transformation!}

# %% [markdown]
# # Intro 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = b"b9yPw:MwqcoHuFz^r-o*{>I.Y"

# %%
for i,byte in enumerate(data):
    byte = byte ^ ((i + 0xa) % 256)
    byte = (byte - 2) % 256

# %%
# %%bash
# (sleep 1 && echo "n0w_w3_have_a_dyn4m1c_k3y!") | ncat --ssl-verify d307c732b8ebb2b03ba83f98-1024-intro-rev-3.challenge.cscg.live 1337
# Out:
# Give me your password:
# Thats the right password!
# Flag: CSCG{X0R_and_sub_is_a_n1ce_c0mbinati0n}
